# %%
import sys
import tomotopy as tp
import numpy as np
import re
import nltk
import pandas as pd
from bs4 import BeautifulSoup

def train(model, save_path):
    model.train(0)
    print('Num docs:', len(model.docs), ', Vocab size:', len(model.used_vocabs), ', Num words:', model.num_words)
    print('Removed top words:', model.removed_top_words)
    print('Training...', file=sys.stderr, flush=True)
    for _ in range(0, 200, 10):
        model.train(7)
        model.train(3, freeze_topics=True)
        print('Iteration: {:05}\tll per word: {:.5f}'.format(model.global_step, model.ll_per_word))

    for _ in range(0, 100, 10):
        model.train(10, freeze_topics=True)
        print('Iteration: {:05}\tll per word: {:.5f}'.format(model.global_step, model.ll_per_word))

    print('Saving...', file=sys.stderr, flush=True)
    model.save(save_path, True)
    
    


tenders_structured_path = r"UpdatedAgainTenders.xlsx"

tenders_structured = pd.read_excel(tenders_structured_path)
tenders_structured = tenders_structured[["Reference Number", "Contract Title", "Description"]].dropna(subset=["Reference Number"]).drop_duplicates()

def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    cleaned = soup.get_text().replace('\xa0', ' ')
    cleaned = ' '.join(cleaned.split())
    return cleaned


from nltk.corpus import stopwords
try:
    corpus = tp.utils.Corpus.load('tender.cached.corpus')
except IOError:
    docs = []
    for index, row in tenders_structured.iterrows():
        title = row["Contract Title"]
        desc = remove_html_tags(row["Description"])
        docs.append(title + " " + desc)
    stops = set(stopwords.words('english'))
    corpus = tp.utils.Corpus(
        tokenizer=tp.utils.SimpleTokenizer(), # leave empty tokenizer as it doesnt seem to work without 
        stopwords=lambda x: len(x) <= 2 or x in stops
    )
    corpus.process(docs)
    corpus.save('tender.cached.corpus')

model = tp.HPAModel(tw=tp.TermWeight.ONE, k1=10, k2=100, rm_top=0, corpus=corpus)
train(model, "struc_tender.hpa.tmm")
# Out:
# KeyboardInterrupt

# %%
import sys
import tomotopy as tp
import numpy as np
import re
import nltk
import pandas as pd
from bs4 import BeautifulSoup
def remove_html_tags(text):
    soup = BeautifulSoup(text, "html.parser")
    cleaned = soup.get_text().replace('\xa0', ' ')
    cleaned = ' '.join(cleaned.split())
    return cleaned
tenders_structured_path = r"UpdatedAgainTenders.xlsx"

tenders_structured = pd.read_excel(tenders_structured_path)
tenders_structured = tenders_structured[["Reference Number", "Contract Title", "Description"]].dropna(subset=["Reference Number"]).drop_duplicates()
docs = []
for index, row in tenders_structured.iterrows():
        title = row["Contract Title"]
        desc = remove_html_tags(row["Description"])
        docs.append(title + " " + desc)

# %%
model = tp.HPAModel.load("struc_tender.hpa.tmm")

# %%
doc_index = 0
doc = model.docs[doc_index]
topic_probs = doc.get_topics()
print("Topic probabilities for document {}:".format(doc_index))
for topic, prob in topic_probs:
    print("Topic {}: {:.4f}".format(topic, prob))
# Out:
# Topic probabilities for document 0:
# Topic 8: 0.3729
# Topic 15: 0.2583
# Topic 98: 0.1845
# Topic 31: 0.1107
# Topic 40: 0.0738
# Topic 7: 0.0072
# Topic 4: 0.0035
# Topic 9: 0.0023
# Topic 5: 0.0020
# Topic 1: 0.0014

# %%
# Get the topic probabilities for the first document (index 0)
doc_index = 0
doc = model.docs[doc_index]
topic_probs = doc.get_topics()

print("Topic probabilities for document {}:".format(doc_index))

# Create a dictionary to store topic names
topic_names = {}

# Loop through the topics and store the top words as topic names
for topic_id, prob in topic_probs:
    topic_words = model.get_topic_words(topic_id, top_n=5)  # Adjust top_n as needed
    topic_name = ", ".join([word for word, weight in topic_words])
    topic_names[topic_id] = topic_name
    print("Topic {} ({}): {:.4f}".format(topic_id, topic_name, prob))

# Now you can access topic names using the topic_id
#for topic_id, topic_name in topic_names.items():
    #print("Topic {}: {}".format(topic_id, topic_name))
# Out:
# Topic probabilities for document 0:
# Topic 8 (pta, required, shall, contractor, scope): 0.3729
# Topic 15 (centre, state, health, services, coordination): 0.2583
# Topic 98 (road, provision, traffic, services, supply): 0.1845
# Topic 31 (supply, installation, delivery, equipment, maintenance): 0.1107
# Topic 40 (project, conservation, perth, plan, biodiversity): 0.0738
# Topic 7 (government, provide, future, needs, state): 0.0072
# Topic 4 (requirements, system, systems, business, current): 0.0035
# Topic 9 (project, change, management, manager, business): 0.0023
# Topic 5 (program, services, work, personnel, experience): 0.0020
# Topic 1 (pta, project, train, rail, signalling): 0.0014

# %%
def get_topic_distribution(model,document_index,n,with_topics=True):
    '''
    model: An HPA model 
    document_index: an index corresponding to the tender list used to train the model
    n: the number of topics you want returned in order of highest to lowest probability
    with_topics: boolean, if you want topic index, or topic name returned
    
    returns the topic distribution for a single document in the form of a list of tupals, of format [(list of topic words,prob),...] 
    '''
    doc = model.docs[doc_index]
    topic_probs = doc.get_topics()[:n:]
    output = []
    
   
        
    if with_topics:
        for topic_id, prob in topic_probs:
            topic_words = model.get_topic_words(topic_id, top_n=5) 
            words_temp = ", ".join([word for word, weight in topic_words])
            output.append((words_temp,round(prob,4)))
        return output
    else:
        return topic_probs

# %%
get_topic_distribution(model,0,2)
# Out:
# [('pta, required, shall, contractor, scope', 0.3729),
#  ('centre, state, health, services, coordination', 0.2583)]

# %%
model.get_sub_topics(0)
# Out:
# [(85, 0.05263254791498184),
#  (68, 0.029912302270531654),
#  (92, 0.023323440924286842),
#  (11, 0.022876355797052383),
#  (79, 0.02126314677298069),
#  (58, 0.0212631206959486),
#  (16, 0.020874321460723877),
#  (75, 0.0206608884036541),
#  (44, 0.02046625129878521),
#  (20, 0.02023320458829403)]

# %%
model.summary()
# Out:
# <Basic Info>
# | HPAModel (current version: 0.12.5)
# | 20625 docs, 614519 words
# | Total Vocabs: 24872, Used Vocabs: 24872
# | Entropy of words: 7.70177
# | Entropy of term-weighted words: 7.70177
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 300, Burn-in steps: 0
# | Optimization Interval: 1
# | Log-likelihood per word: -9.62379
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k1: 10 (the number of super topics between 1 ~ 32767)
# | k2: 100 (the number of sub topics between 1 ~ 32767)
# | alpha: [0.1] (initial hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k1 + 1` of `float` in case of asymmetric prior.)
# | subalpha: [0.1] (initial hyperparameter of Dirichlet distribution for super-sub topic, given as a single `float` in case of symmetric prior and as a list with length `k2 + 1` of `float` in case of asymmetric prior.)
# |    0.01632334 0.01319348 0.00976324 0.0118424  0.01273462 0.01676473
# |    0.01317814 0.01536566 0.01641276 0.01283428 0.01299456 0.017368
# |    0.00942863 0.01390677 0.01550476 0.01309754 0.01416749 0.01306184
# |    0.01505604 0.01137728 0.0118675  0.01440773 0.01630506 0.00778254
# |    0.01146488 0.01389232 0.00859151 0.01696859 0.01360066 0.0116106
# |    0.01345909 0.01496723 0.01409554 0.01911776 0.00687644 0.01371569
# |    0.00772632 0.01171683 0.02720033 0.02348503 0.01745553 0.01588065
# |    0.00943752 0.0145811  0.01931555 0.0241732  0.0140441  0.0177542
# |    0.02407678 0.02181125 0.01077923 0.01168071 0.01691848 0.01754164
# |    0.00905302 0.02333244 0.01663622 0.0105408  0.00749318 0.01266899
# |    0.01087702 0.01046202 0.02200215 0.02342802 0.00770084 0.01021727
# |    0.01562356 0.01374848 0.0102937  0.00831673]
# | eta (Dirichlet prior on the per-subtopic word distribution)
# |  0.01
# |
# <Topics>
# | Top-topic (23178) : works management department ltd pty
# | Super-topics
# |  #Super0 (3839) : pta project train rail signalling
# |    its sub-topics : #85 #68 #92 #11 #79
# |  #Super1 (2077) : developer services icwa work applications
# |    its sub-topics : #85 #68 #11 #79 #69
# |  #Super2 (3518) : service bus school contract transport
# |    its sub-topics : #85 #68 #11 #79 #27
# |  #Super3 (6547) : requirements system systems business current
# |    its sub-topics : #13 #85 #69 #75 #92
# |  #Super4 (9083) : program services work personnel experience
# |    its sub-topics : #85 #68 #69 #11 #13
# |  #Super5 (2507) : health aboriginal workshops engagement hss
# |    its sub-topics : #85 #16 #11 #68 #79
# |  #Super6 (15495) : government provide future needs state
# |    its sub-topics : #79 #85 #69 #16 #74
# |  #Super7 (9595) : pta required shall contractor scope
# |    its sub-topics : #85 #63 #79 #68 #11
# |  #Super8 (6112) : project change management manager business
# |    its sub-topics : #85 #68 #11 #14 #69
# |  #Super9 (3065) : modelling model traffic stage type
# |    its sub-topics : #85 #11 #68 #69 #92
# | Sub-topics
# |  #0 (2868) : commission study products forest halls
# |  #1 (5983) : health service medical wachs clinical
# |  #2 (5865) : communities department housing refurbishment sherp
# |  #3 (2399) : park board specification per victoria
# |  #4 (2737) : centre state health services coordination
# |  #5 (3799) : security services provision monitoring cyber
# |  #6 (5893) : tafe training campus workforce development
# |  #7 (3121) : systems replacement project radio engineer
# |  #8 (4184) : service bus school transport contract
# |  #9 (5688) : site investigation environmental sites remediation
# |  #10 (2501) : west south consultant lead region
# |  #11 (13712) : high school education department senior
# |  #12 (4388) : vessel boat harbour removal maritime
# |  #13 (9480) : data services solution microsoft provision
# |  #14 (8629) : services project management program provision
# |  #15 (6352) : support maintenance software renewal subscription
# |  #16 (10629) : health service services community mental
# |  #17 (2381) : centre hill support facility banksia
# |  #18 (5806) : training provision western department education
# |  #19 (2738) : centre management clinic event support
# |  #20 (8543) : supply installation delivery equipment maintenance
# |  #21 (3370) : covid-19 emergency response services purchase
# |  #22 (4616) : management risk framework development assessment
# |  #23 (4693) : laboratory pathwest medicine purchase testing
# |  #24 (2773) : learning storage online provision modules
# |  #25 (7233) : maintenance provision various systems sites
# |  #26 (2190) : hbf stadium arena centre venueswest
# |  #27 (9104) : temporary officer personnel support provision
# |  #28 (6008) : road highway works great slk
# |  #29 (2886) : project conservation perth plan biodiversity
# |  #30 (4880) : case engineering business building services
# |  #31 (2009) : street geraldton refurbishment lot exmouth
# |  #32 (2488) : fremantle hospital general rockingham south
# |  #33 (4020) : prison justice department waste regional
# |  #34 (6670) : police force western australia station
# |  #35 (6640) : design construction works construct access
# |  #36 (3388) : supply delivery one bus passenger
# |  #37 (3087) : supply purchase order delivery equipment
# |  #38 (9556) : contract period 2023 year term
# |  #39 (2706) : electricity cuaelc2012 court grove wattle
# |  #40 (3624) : station perth stations platform design
# |  #41 (5852) : business services analyst provision analysis
# |  #42 (2621) : financial services support infrastructure additional
# |  #43 (3463) : program evaluation department review development
# |  #44 (10093) : strategy research western development tourism
# |  #45 (5224) : development regional primary industries department
# |  #46 (3810) : data survey western australia collection
# |  #47 (2088) : river swan pool margaret plant
# |  #48 (5421) : network services supply equipment infrastructure
# |  #49 (4701) : building work construction project code
# |  #50 (4759) : fitout office perth street department
# |  #51 (3224) : design master media planning plan
# |  #52 (4453) : services provision heritage aboriginal advisory
# |  #53 (2796) : kimberley broome fencing provision fence
# |  #54 (3049) : island rottnest authority ria design
# |  #55 (3064) : main roads supply western australia
# |  #56 (2341) : support oracle services database program
# |  #57 (5307) : college education department secondary arts
# |  #58 (6790) : health service country campus services
# |  #59 (4706) : fire services emergency dfes department
# |  #60 (2166) : leadership development executive external advisor
# |  #61 (3939) : provision temporary personnel cua services
# |  #62 (3130) : vehicle kalgoorlie heavy services vehicles
# |  #63 (8710) : new block works existing refurbishment
# |  #64 (2361) : college agriculture narrogin australian esperance
# |  #65 (5482) : project line station rail engineer
# |  #66 (4119) : safety industry mines regulation dmirs
# |  #67 (2749) : supply gas audio premier visual
# |  #68 (15916) : school primary education department installation
# |  #69 (12386) : system management solution information support
# |  #70 (8463) : hospital health service perth metropolitan
# |  #71 (3152) : rail extension yanchep link project
# |  #72 (2612) : 2020 roof replacement 2019 2021
# |  #73 (3844) : air seeking offers request provision
# |  #74 (7591) : review independent assessment act report
# |  #75 (11146) : services qualified suitably seeking experienced
# |  #76 (8335) : project projects services delivery design
# |  #77 (7688) : services architectural panel department management
# |  #78 (3087) : park maintenance toilet national dbca
# |  #79 (13625) : panel contract services required arrangement
# |  #80 (3619) : bus depot facility car pta
# |  #81 (4317) : lot construction hedland street dwelling
# |  #82 (4713) : cultural government local industries sport
# |  #83 (6123) : water new supply system construction
# |  #84 (3962) : hospital health service nmhs north
# |  #85 (24834) : tender briefing site attendance held
# |  #86 (2277) : upgrade cctv fitzroy western park
# |  #87 (2664) : road provision traffic services supply
# |  #88 (2743) : community remote services aboriginal municipal
# |  #89 (5472) : services provision developer development application
# |  #90 (2233) : units video unit mobile assessment
# |  #91 (2884) : replacement bridge ceiling structure repairs
# |  #92 (10355) : transport public services department perth
# |  #93 (6527) : services cleaning provision office department
# |  #94 (2719) : price environmental tom supply analysis
# |  #95 (3706) : electrical power upgrade supply works
# |  #96 (5756) : works repairs wall structural concrete
# |  #97 (4244) : care program services support aged
# |  #98 (3232) : services cloud data provision private
# |  #99 (3223) : communities structure shade services department
# |
