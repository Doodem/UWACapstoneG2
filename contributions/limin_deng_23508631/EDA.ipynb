# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
import pickle

# %%
# Read the Excel file into a DataFrame
df = pd.read_excel('tender_postcode.xlsx') 

# Extract the columns we need
df = df[['Client Agency', 'Reference Number', 'Type of Work', 'Contract Title', 'Description', 'UNSPSC Title', 'Supplier Name', 'Supplier ABN']]

# %%
def remove_html_tags(text):
    return BeautifulSoup(text, "html.parser").get_text()

# %%
# remove the html format
df['Description'] = df['Description'].apply(remove_html_tags)

# %%
unique_suppliers_count = df['Supplier Name'].nunique()
unique_unspc_title = df['UNSPSC Title'].nunique()
print(f"There are {unique_suppliers_count} unique supplier names.")
print(f"There are {unique_unspc_title} unique UNSPSC Title.")
# Out:
# There are 6693 unique supplier names.
# There are 2336 unique UNSPSC Title.

# %%
df['merged_title'] = df['Contract Title'] + ' ' + ['UNSPSC Title']

# %%
df_title = df[[ 'Reference Number',  'merged_title']]

# %%
df_title = df_title.rename(columns={
    'Reference Number': 'ref_num'
})
# Out:
#                     ref_num                                       merged_title
# 0              ARA201901891  supply and delivery of aspen bedding material ...
# 1                 20221AGWA  bar consultancy and staffing agwa rooftop bar ...
# 2             FIN873DLGSCAG  investment services for art gallery wa unspsc ...
# 3                2020153WAM        provision of audience research unspsc title
# 4      CUAHRS202117042023AC   consultancy services for hr support unspsc title
# ...                     ...                                                ...
# 26470               WCT0119  provision of electricity services for workcove...
# 26471               WCV0119  redevelop workcover wa conference website in w...
# 26472               WCQ0219  core business systems technology refresh  unsp...
# 26473               WCQ0219  core business systems technology refresh  unsp...
# 26474               WCE0119  digital first conciliation and arbitration ser...
#
# [26475 rows x 2 columns]

# %%
# Apply a first round of text cleaning techniques
import re
import string

def clean_text(text):
    '''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
    text = text.lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return text

# %%
# Let's take a look at the updated text
df_title['merged_title'] = df_title['merged_title'].apply(clean_text)
df_title
# Out:
#                     ref_num                                       merged_title
# 0              ARA201901891  supply and delivery of aspen bedding material ...
# 1                 20221AGWA  bar consultancy and staffing agwa rooftop bar ...
# 2             FIN873DLGSCAG  investment services for art gallery wa unspsc ...
# 3                2020153WAM        provision of audience research unspsc title
# 4      CUAHRS202117042023AC   consultancy services for hr support unspsc title
# ...                     ...                                                ...
# 26470               WCT0119  provision of electricity services for workcove...
# 26471               WCV0119  redevelop workcover wa conference website in w...
# 26472               WCQ0219  core business systems technology refresh  unsp...
# 26473               WCQ0219  core business systems technology refresh  unsp...
# 26474               WCE0119  digital first conciliation and arbitration ser...
#
# [26475 rows x 2 columns]

# %%
# Let's pickle it for later use
df_title.to_pickle("corpus.pkl")

# %%
# We are going to create a document-term matrix using CountVectorizer, and exclude common English stop words
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(stop_words='english')
data_cv = cv.fit_transform(df_title.merged_title)
data_dtm = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_dtm.index = df_title.ref_num
data_dtm
# Out:
#                       aasb  aat  aats  ab  abalone  abandoned  abattoir  \
# ref_num
# ARA201901891             0    0     0   0        0          0         0
# 20221AGWA                0    0     0   0        0          0         0
# FIN873DLGSCAG            0    0     0   0        0          0         0
# 2020153WAM               0    0     0   0        0          0         0
# CUAHRS202117042023AC     0    0     0   0        0          0         0
# ...                    ...  ...   ...  ..      ...        ...       ...
# WCT0119                  0    0     0   0        0          0         0
# WCV0119                  0    0     0   0        0          0         0
# WCQ0219                  0    0     0   0        0          0         0
# WCQ0219                  0    0     0   0        0          0         0
# WCE0119                  0    0     0   0        0          0         0
#
#                       abbott  abbottst  aberdeen  ...  zk  zo  zone  zones  \
# ref_num                                           ...
# ARA201901891               0         0         0  ...   0   0     0      0
# 20221AGWA                  0         0         0  ...   0   0     0      0
# FIN873DLGSCAG              0         0         0  ...   0   0     0      0
# 2020153WAM                 0         0         0  ...   0   0     0      0
# CUAHRS202117042023AC       0         0         0  ...   0   0     0      0
# ...                      ...       ...       ...  ...  ..  ..   ...    ...
# WCT0119                    0         0         0  ...   0   0     0      0
# WCV0119                    0         0         0  ...   0   0     0      0
# WCQ0219                    0         0         0  ...   0   0     0      0
# WCQ0219                    0         0         0  ...   0   0     0      0
# WCE0119                    0         0         0  ...   0   0     0      0
#
#                       zoo  zoological  zoology  zoom  zscaler  zuytdorp
# ref_num
# ARA201901891            0           0        0     0        0         0
# 20221AGWA               0           0        0     0        0         0
# FIN873DLGSCAG           0           0        0     0        0         0
# 2020153WAM              0           0        0     0        0         0
# CUAHRS202117042023AC    0           0        0     0        0         0
# ...                   ...         ...      ...   ...      ...       ...
# WCT0119                 0           0        0     0        0         0
# WCV0119                 0           0        0     0        0         0
# WCQ0219                 0           0        0     0        0         0
# WCQ0219                 0           0        0     0        0         0
# WCE0119                 0           0        0     0        0         0
#
# [26475 rows x 10797 columns]

# %%
# Let's pickle it for later use
data_dtm.to_pickle("dtm.pkl")

# %%
# Let's also pickle the cleaned data (before we put it in document-term matrix format) and the CountVectorizer object
df_title.to_pickle('df_title.pkl')
pickle.dump(cv, open("cv.pkl", "wb"))

# %%
data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head(500)
# Out:
# ref_num         ARA201901891  20221AGWA  FIN873DLGSCAG  2020153WAM  \
# aasb                       0          0              0           0
# aat                        0          0              0           0
# aats                       0          0              0           0
# ab                         0          0              0           0
# abalone                    0          0              0           0
# ...                      ...        ...            ...         ...
# arboricultural             0          0              0           0
# arborist                   0          0              0           0
# arc                        0          0              0           0
# arcgis                     0          0              0           0
# archaeological             0          0              0           0
#
# ref_num         CUAHRS202117042023AC  RFQ13042023ACT  E03052023ACT  \
# aasb                               0               0             0
# aat                                0               0             0
# aats                               0               0             0
# ab                                 0               0             0
# abalone                            0               0             0
# ...                              ...             ...           ...
# arboricultural                     0               0             0
# arborist                           0               0             0
# arc                                0               0             0
# arcgis                             0               0             0
# archaeological                     0               0             0
#
# ref_num         RFQ06122022ACT2  CUAAFA201807032023AC  CUAPCS201829112022AC  \
# aasb                          0                     0                     0
# aat                           0                     0                     0
# aats                          0                     0                     0
# ab                            0                     0                     0
# abalone                       0                     0                     0
# ...                         ...                   ...                   ...
# arboricultural                0                     0                     0
# arborist                      0                     0                     0
# arc                           0                     0                     0
# arcgis                        0                     0                     0
# archaeological                0                     0                     0
#
# ref_num         ...  WCQ0220  WCQ0220  WCQ0220  WCQ0120  WCQ0122  WCT0119  \
# aasb            ...        0        0        0        0        0        0
# aat             ...        0        0        0        0        0        0
# aats            ...        0        0        0        0        0        0
# ab              ...        0        0        0        0        0        0
# abalone         ...        0        0        0        0        0        0
# ...             ...      ...      ...      ...      ...      ...      ...
# arboricultural  ...        0        0        0        0        0        0
# arborist        ...        0        0        0        0        0        0
# arc             ...        0        0        0        0        0        0
# arcgis          ...        0        0        0        0        0        0
# archaeological  ...        0        0        0        0        0        0
#
# ref_num         WCV0119  WCQ0219  WCQ0219  WCE0119
# aasb                  0        0        0        0
# aat                   0        0        0        0
# aats                  0        0        0        0
# ab                    0        0        0        0
# abalone               0        0        0        0
# ...                 ...      ...      ...      ...
# arboricultural        0        0        0        0
# arborist              0        0        0        0
# arc                   0        0        0        0
# arcgis                0        0        0        0
# archaeological        0        0        0        0
#
# [500 rows x 26475 columns]

# %%
# Find the top 5 words of each tender
top_dict = {}
for r in data.columns:
    column_data = data.loc[:, r]
    
    # Check if column_data is a DataFrame
    if isinstance(column_data, pd.DataFrame):
        column_data = column_data.iloc[:, 0]  # Take the first column to get a Series
    
    top = column_data.sort_values(ascending=False).head(10)
    top_dict[r] = list(zip(top.index, top.values))

top_dict
# Out:
# {'ARA201901891': [('material', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('aspen', 1),
#   ('bedding', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  '20221AGWA': [('bar', 3),
#   ('agwa', 2),
#   ('title', 1),
#   ('café', 1),
#   ('staffing', 1),
#   ('consultancy', 1),
#   ('rooftop', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plasticware', 0)],
#  'FIN873DLGSCAG': [('wa', 1),
#   ('gallery', 1),
#   ('art', 1),
#   ('investment', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  '2020153WAM': [('provision', 1),
#   ('title', 1),
#   ('audience', 1),
#   ('unspsc', 1),
#   ('research', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CUAHRS202117042023AC': [('unspsc', 1),
#   ('services', 1),
#   ('consultancy', 1),
#   ('hr', 1),
#   ('title', 1),
#   ('support', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'RFQ13042023ACT': [('strategic', 1),
#   ('consultancy', 1),
#   ('services', 1),
#   ('corporate', 1),
#   ('unspsc', 1),
#   ('support', 1),
#   ('title', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'E03052023ACT': [('support', 1),
#   ('title', 1),
#   ('interim', 1),
#   ('corporate', 1),
#   ('communications', 1),
#   ('unspsc', 1),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0),
#   ('platform', 0)],
#  'RFQ06122022ACT2': [('elevated', 1),
#   ('unspsc', 1),
#   ('periodic', 1),
#   ('work', 1),
#   ('title', 1),
#   ('platform', 1),
#   ('inspection', 1),
#   ('maintenance', 1),
#   ('equipment', 1),
#   ('routine', 1)],
#  'CUAAFA201807032023AC': [('review', 1),
#   ('consultancy', 1),
#   ('charges', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('venue', 1),
#   ('playgrounds', 0),
#   ('playground', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CUAPCS201829112022AC': [('unspsc', 1),
#   ('mfds', 1),
#   ('multifunction', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('platinum', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0),
#   ('platform', 0)],
#  'WR05042022ACT': [('works', 1),
#   ('services', 1),
#   ('cabling', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('streaming', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'E19012023ACT': [('unspsc', 1),
#   ('desk', 1),
#   ('audio', 1),
#   ('title', 1),
#   ('hire', 1),
#   ('playground', 0),
#   ('player', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'E10022023ACT': [('food', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('catering', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'E14122022ACT': [('aec', 1),
#   ('supply', 1),
#   ('installation', 1),
#   ('services', 1),
#   ('streaming', 1),
#   ('cables', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platforms', 0)],
#  'E29112022ACT': [('health', 1),
#   ('consultant', 1),
#   ('work', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('safety', 1),
#   ('whs', 1),
#   ('playground', 0),
#   ('playgroup', 0),
#   ('plasterglass', 0)],
#  'RFQ08042022ACT': [('maintenance', 1),
#   ('equipment', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('rigging', 1),
#   ('service', 1),
#   ('playgrounds', 0),
#   ('playgroup', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'E11102022ACT': [('unspsc', 1),
#   ('lighting', 1),
#   ('christmas', 1),
#   ('project', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'RFQ06042022PTT': [('aid', 2),
#   ('health', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('title', 1),
#   ('kits', 1),
#   ('training', 1),
#   ('event', 1),
#   ('playground', 0),
#   ('plastics', 0)],
#  'RFQ06072022ACT': [('security', 2),
#   ('title', 1),
#   ('crowd', 1),
#   ('mobile', 1),
#   ('patrols', 1),
#   ('nightly', 1),
#   ('static', 1),
#   ('unspsc', 1),
#   ('provision', 1),
#   ('controllers', 1)],
#  'E12072022ACT': [('onsite', 1),
#   ('management', 1),
#   ('contractor', 1),
#   ('visitor', 1),
#   ('unspsc', 1),
#   ('employee', 1),
#   ('title', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'E05072022ACT': [('change', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('positioning', 1),
#   ('procurement', 1),
#   ('title', 1),
#   ('management', 1),
#   ('planning', 1),
#   ('strategic', 1),
#   ('consultancy', 1)],
#  'RFQ05042022PTT': [('title', 1),
#   ('pest', 1),
#   ('services', 1),
#   ('provision', 1),
#   ('management', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CUATPS201907072022AC': [('unspsc', 1),
#   ('policy', 1),
#   ('officer', 1),
#   ('senior', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'E10042022PTT': [('title', 1),
#   ('signage', 1),
#   ('supply', 1),
#   ('installation', 1),
#   ('digital', 1),
#   ('unspsc', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CUATPS201914062022PT': [('title', 1),
#   ('contracts', 1),
#   ('officer', 1),
#   ('procurement', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CUATPS201908042022PT': [('financial', 1),
#   ('temporary', 1),
#   ('officer', 1),
#   ('chief', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  '07012022PTT': [('supply', 1),
#   ('staging', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('unspsc', 1),
#   ('courtyard', 1),
#   ('playgroup', 0),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  '02022021DLGSCPTT': [('unspsc', 1),
#   ('live', 1),
#   ('equipment', 1),
#   ('streaming', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('platforms', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  '04022022CUATP2019': [('director', 1),
#   ('corporate', 1),
#   ('communications', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plate', 0),
#   ('plates', 0),
#   ('platform', 0),
#   ('platforms', 0)],
#  '18122020DLGSCPTT': [('title', 1),
#   ('centre', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('entertainment', 1),
#   ('provision', 1),
#   ('unspsc', 1),
#   ('albany', 1),
#   ('aasb', 0),
#   ('plate', 0)],
#  '02122020DLGSCPTT': [('aec', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('backstage', 1),
#   ('installation', 1),
#   ('provision', 1),
#   ('wireless', 1),
#   ('unspsc', 1),
#   ('communication', 1),
#   ('plates', 0)],
#  '204340DLGSC': [('precinct', 1),
#   ('unspsc', 1),
#   ('perth', 1),
#   ('provision', 1),
#   ('services', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('garden', 1),
#   ('cultural', 1),
#   ('centre', 1)],
#  'PTT05062019': [('title', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('audit', 1),
#   ('internal', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  '3092020DLGSCPTT': [('provision', 1),
#   ('payroll', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plasterboard', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'E20402DLGSCPTT': [('service', 1),
#   ('maintenance', 1),
#   ('technical', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('unspsc', 1),
#   ('stcwa', 1),
#   ('plate', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'E20400DLGSCPTT': [('roster', 1),
#   ('hosting', 1),
#   ('services', 1),
#   ('software', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('scheduling', 1),
#   ('management', 1),
#   ('provision', 1),
#   ('plate', 0)],
#  'E2019192449DLGSCPTT': [('state', 1),
#   ('fly', 1),
#   ('technical', 1),
#   ('theatre', 1),
#   ('title', 1),
#   ('automated', 1),
#   ('provision', 1),
#   ('unspsc', 1),
#   ('support', 1),
#   ('wa', 1)],
#  'E2019CA1958DLGSCPTT': [('realm', 1),
#   ('public', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('theatre', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('general', 1),
#   ('trust', 1),
#   ('perth', 1)],
#  'INF4CA20199': [('redevelopment', 1),
#   ('theatre', 1),
#   ('majestys', 1),
#   ('stage', 1),
#   ('house', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('plasticware', 0),
#   ('plaster', 0),
#   ('plasterboard', 0)],
#  'DBCABGPA20202023': [('electricity', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('bundled', 1),
#   ('unbundled', 1),
#   ('unspsc', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20052023': [('supply', 1),
#   ('turf', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('delivery', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20122023': [('mounts', 1),
#   ('unspsc', 1),
#   ('bay', 1),
#   ('rectification', 1),
#   ('chainage', 1),
#   ('title', 1),
#   ('park', 1),
#   ('fence', 1),
#   ('safety', 1),
#   ('road', 1)],
#  'DBCABGPA10452022': [('delivery', 1),
#   ('products', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('bathroom', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20022023': [('maintenance', 1),
#   ('monitoring', 1),
#   ('deep', 1),
#   ('provision', 1),
#   ('sewerage', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('title', 1),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA10072023': [('unspsc', 1),
#   ('bgpa', 1),
#   ('financial', 1),
#   ('management', 1),
#   ('title', 1),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA30162023': [('health', 1),
#   ('unspsc', 1),
#   ('equipment', 1),
#   ('surveillance', 1),
#   ('tree', 1),
#   ('title', 1),
#   ('monitoring', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20032023': [('licence', 1),
#   ('repairs', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('irrigation', 1),
#   ('maintenance', 1),
#   ('plates', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCABGPA30362022': [('repairs', 1),
#   ('title', 1),
#   ('significant', 1),
#   ('glasshouse', 1),
#   ('unspsc', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20512022': [('turn', 1),
#   ('unspsc', 1),
#   ('zero', 1),
#   ('title', 1),
#   ('mower', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('playgrounds', 0),
#   ('plaster', 0),
#   ('plasterboard', 0)],
#  'DBCABGPA20442022': [('firefighters', 1),
#   ('title', 1),
#   ('extension', 1),
#   ('grove', 1),
#   ('unspsc', 1),
#   ('memorial', 1),
#   ('plate', 0),
#   ('plates', 0),
#   ('platform', 0),
#   ('platforms', 0)],
#  'DBCABGPA20462022': [('supply', 1),
#   ('plus', 1),
#   ('vehicle', 1),
#   ('electric', 1),
#   ('trade', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('plates', 0),
#   ('plasterglass', 0)],
#  'DBCABGPA20012022': [('maintenance', 2),
#   ('value', 1),
#   ('establish', 1),
#   ('services', 1),
#   ('low', 1),
#   ('unspsc', 1),
#   ('building', 1),
#   ('panel', 1),
#   ('title', 1),
#   ('aasb', 0)],
#  'DBCABGPA20292022': [('restoration', 2),
#   ('unspsc', 1),
#   ('heritage', 1),
#   ('provision', 1),
#   ('plaques', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('value', 1),
#   ('stone', 1),
#   ('high', 1)],
#  'DBCABGPA20242022': [('bold', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('park', 1),
#   ('herbicide', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('spraying', 1),
#   ('bushland', 1),
#   ('play', 0)],
#  'DBCABGPA20142022': [('irrigation', 1),
#   ('provision', 1),
#   ('civil', 1),
#   ('panel', 1),
#   ('unspsc', 1),
#   ('earthworks', 1),
#   ('title', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20112022': [('title', 1),
#   ('cleaning', 1),
#   ('exterior', 1),
#   ('services', 1),
#   ('bbq', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA20172022': [('delivery', 1),
#   ('chipper', 1),
#   ('plus', 1),
#   ('trade', 1),
#   ('wood', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('aasb', 0),
#   ('plasterboard', 0)],
#  'DBCABGPA20232022': [('vehicles', 1),
#   ('unspsc', 1),
#   ('plus', 1),
#   ('trade', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('electric', 1),
#   ('play', 0),
#   ('plasticware', 0)],
#  'DBCABGPA30242021': [('upgrade', 1),
#   ('biodiversity', 1),
#   ('conservation', 1),
#   ('title', 1),
#   ('air', 1),
#   ('culture', 1),
#   ('laboratory', 1),
#   ('centre', 1),
#   ('unspsc', 1),
#   ('conditioning', 1)],
#  'DBCABGPA20272022': [('acid', 2),
#   ('dosing', 1),
#   ('unspsc', 1),
#   ('sulfuric', 1),
#   ('irrigation', 1),
#   ('title', 1),
#   ('bulk', 1),
#   ('plan', 0),
#   ('platfrom', 0),
#   ('plastics', 0)],
#  'DBCABGPA20162022': [('supply', 1),
#   ('trade', 1),
#   ('unspsc', 1),
#   ('mower', 1),
#   ('delivery', 1),
#   ('title', 1),
#   ('minus', 1),
#   ('outfront', 1),
#   ('platforms', 0),
#   ('plastic', 0)],
#  'DBCABGPA10202022': [('conduct', 1),
#   ('kings', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('park', 1),
#   ('title', 1),
#   ('study', 1),
#   ('events', 1),
#   ('consultancy', 1),
#   ('feasibility', 1)],
#  'DBCABGPA20192022': [('waste', 1),
#   ('green', 1),
#   ('park', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('annual', 1),
#   ('processing', 1),
#   ('kings', 1),
#   ('play', 0),
#   ('plates', 0)],
#  'DBCABGPA20092022': [('storm', 1),
#   ('provision', 1),
#   ('road', 1),
#   ('cleaning', 1),
#   ('sweeping', 1),
#   ('services', 1),
#   ('water', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plastics', 0)],
#  'DBCABGPA10122022': [('security', 2),
#   ('patrols', 1),
#   ('adhoc', 1),
#   ('services', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('mobile', 1),
#   ('playgrounds', 0),
#   ('plaza', 0)],
#  'DBCABGPA20222022': [('fountains', 1),
#   ('unspsc', 1),
#   ('bent', 1),
#   ('title', 1),
#   ('water', 1),
#   ('public', 1),
#   ('supply', 1),
#   ('leaf', 1),
#   ('play', 0),
#   ('playgrounds', 0)],
#  'DBCABGPA20102022': [('park', 2),
#   ('bin', 2),
#   ('enclosure', 1),
#   ('kings', 1),
#   ('unspsc', 1),
#   ('provision', 1),
#   ('cleaning', 1),
#   ('title', 1),
#   ('services', 1),
#   ('bold', 1)],
#  'DBCABGPA10312021': [('facilities', 1),
#   ('public', 1),
#   ('toilet', 1),
#   ('unspsc', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('title', 1),
#   ('park', 1),
#   ('bgpa', 1),
#   ('kings', 1)],
#  'DBCABGPA20152022': [('unspsc', 1),
#   ('advisory', 1),
#   ('services', 1),
#   ('management', 1),
#   ('project', 1),
#   ('title', 1),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20102021': [('irrigation', 1),
#   ('services', 1),
#   ('consultancy', 1),
#   ('water', 1),
#   ('unspsc', 1),
#   ('resource', 1),
#   ('title', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA10012021': [('associated', 1),
#   ('provision', 1),
#   ('design', 1),
#   ('products', 1),
#   ('services', 1),
#   ('graphic', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20332021': [('title', 1),
#   ('panel', 1),
#   ('supply', 1),
#   ('supplies', 1),
#   ('unspsc', 1),
#   ('irrigation', 1),
#   ('plate', 0),
#   ('plaster', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'DBCABGPA20302021': [('title', 1),
#   ('damage', 1),
#   ('marr', 1),
#   ('wanju', 1),
#   ('remediation', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20282021': [('unspsc', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('title', 1),
#   ('gutter', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20222021': [('unspsc', 1),
#   ('transfer', 1),
#   ('waste', 1),
#   ('removal', 1),
#   ('kings', 1),
#   ('park', 1),
#   ('station', 1),
#   ('title', 1),
#   ('plate', 0),
#   ('plasterboard', 0)],
#  'DBCABGPA10132021': [('manufacture', 1),
#   ('panel', 1),
#   ('installation', 1),
#   ('unspsc', 1),
#   ('signage', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('plain', 0),
#   ('platinum', 0),
#   ('plasticware', 0)],
#  'DBCABGPA10122021': [('unspsc', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('title', 1),
#   ('facilities', 1),
#   ('office', 1),
#   ('playgrounds', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20172021': [('arboricultural', 1),
#   ('services', 1),
#   ('panel', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20112021': [('unspsc', 1),
#   ('equipment', 1),
#   ('protection', 1),
#   ('systems', 1),
#   ('title', 1),
#   ('service', 1),
#   ('routine', 1),
#   ('playgrounds', 0),
#   ('plates', 0),
#   ('plasterglass', 0)],
#  'DBCABGPA20202021': [('monitoring', 1),
#   ('services', 1),
#   ('data', 1),
#   ('unspsc', 1),
#   ('traffic', 1),
#   ('title', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20152021': [('electricity', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('bundled', 1),
#   ('supply', 1),
#   ('sites', 1),
#   ('police', 0),
#   ('planting', 0),
#   ('plaques', 0),
#   ('plasma', 0)],
#  'DBCABGPA20142021': [('electricity', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('site', 1),
#   ('unbundled', 1),
#   ('title', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA30052021': [('upgrade', 2),
#   ('ac', 2),
#   ('unspsc', 1),
#   ('title', 1),
#   ('tissue', 1),
#   ('bcc', 1),
#   ('services', 1),
#   ('room', 1),
#   ('lab', 1),
#   ('culture', 1)],
#  'DBCABGPA20182021': [('monuments', 1),
#   ('maintenance', 1),
#   ('repairs', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('playground', 0),
#   ('player', 0),
#   ('plasterglass', 0),
#   ('playing', 0),
#   ('plastic', 0)],
#  'DBCABGPA30162021': [('unspsc', 1),
#   ('equipment', 1),
#   ('scientific', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA20072021': [('waste', 1),
#   ('removal', 1),
#   ('green', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20022021': [('watson', 1),
#   ('works', 1),
#   ('construction', 1),
#   ('playground', 1),
#   ('unspsc', 1),
#   ('refurbishment', 1),
#   ('title', 1),
#   ('ivey', 1),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20032021': [('construction', 1),
#   ('unspsc', 1),
#   ('cafe', 1),
#   ('stickybeaks', 1),
#   ('refurbishment', 1),
#   ('works', 1),
#   ('title', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20232020': [('construction', 1),
#   ('fraser', 1),
#   ('avenue', 1),
#   ('unspsc', 1),
#   ('replacement', 1),
#   ('uplights', 1),
#   ('works', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platfrom', 0)],
#  'DBCABGPA20092021': [('equipment', 1),
#   ('play', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA20082021': [('title', 1),
#   ('vehicles', 1),
#   ('electric', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20082021': [('title', 1),
#   ('vehicles', 1),
#   ('electric', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA20212020': [('unspsc', 1),
#   ('upgrade', 1),
#   ('pumping', 1),
#   ('water', 1),
#   ('station', 1),
#   ('treatment', 1),
#   ('title', 1),
#   ('plates', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCABGPA20062021': [('supply', 1),
#   ('tractor', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('delivery', 1),
#   ('aasb', 0),
#   ('plates', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA10202020': [('community', 1),
#   ('garden', 1),
#   ('exhibition', 1),
#   ('pavilion', 1),
#   ('kings', 1),
#   ('ground', 1),
#   ('botanic', 1),
#   ('park', 1),
#   ('unspsc', 1),
#   ('title', 1)],
#  'DBCABGPA20042021': [('mower', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('gang', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20092020': [('kings', 1),
#   ('tower', 1),
#   ('park', 1),
#   ('dna', 1),
#   ('repair', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('recoating', 1),
#   ('plate', 0),
#   ('plasterboard', 0)],
#  'DBCABGPA20142020': [('unspsc', 1),
#   ('roof', 1),
#   ('cafe', 1),
#   ('extension', 1),
#   ('title', 1),
#   ('zamia', 1),
#   ('deck', 1),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA10242020': [('unspsc', 1),
#   ('infringement', 1),
#   ('cloud', 1),
#   ('based', 1),
#   ('management', 1),
#   ('title', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20062020': [('electrical', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('playground', 0),
#   ('player', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA30182020': [('incubators', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plaster', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20162020': [('boiler', 1),
#   ('nursery', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plaster', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20112020': [('unspsc', 1),
#   ('title', 1),
#   ('bushland', 1),
#   ('kings', 1),
#   ('spraying', 1),
#   ('park', 1),
#   ('services', 1),
#   ('herbicide', 1),
#   ('provision', 1),
#   ('plastic', 0)],
#  'DBCABGPA20122020': [('parkland', 1),
#   ('services', 1),
#   ('provision', 1),
#   ('kings', 1),
#   ('unspsc', 1),
#   ('spraying', 1),
#   ('herbicide', 1),
#   ('areas', 1),
#   ('amenity', 1),
#   ('park', 1)],
#  'DBCABGPA10172020': [('venue', 1),
#   ('bookings', 1),
#   ('software', 1),
#   ('management', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCABGPA30132020': [('calorimeter', 1),
#   ('unspsc', 1),
#   ('scanning', 1),
#   ('title', 1),
#   ('differential', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA20072020': [('geotechnical', 1),
#   ('services', 1),
#   ('consultancy', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA20232019': [('title', 1),
#   ('end', 1),
#   ('unspsc', 1),
#   ('loader', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA10242018': [('supply', 1),
#   ('title', 1),
#   ('installation', 1),
#   ('unspsc', 1),
#   ('manufacture', 1),
#   ('customised', 1),
#   ('signage', 1),
#   ('planned', 0),
#   ('player', 0),
#   ('plates', 0)],
#  'DBCABGPA20052020': [('title', 1),
#   ('repairs', 1),
#   ('path', 1),
#   ('concrete', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA20202019': [('title', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('mower', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20262019': [('waste', 1),
#   ('unspsc', 1),
#   ('surrounds', 1),
#   ('bin', 1),
#   ('title', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20222019': [('elevated', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('work', 1),
#   ('unspsc', 1),
#   ('platform', 1),
#   ('plaster', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCABGPA20242019': [('unspsc', 1),
#   ('tractor', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCABGPA20122019': [('unspsc', 1),
#   ('panel', 1),
#   ('services', 1),
#   ('maintenance', 1),
#   ('title', 1),
#   ('general', 1),
#   ('painting', 1),
#   ('play', 0),
#   ('playgrounds', 0),
#   ('plasterglass', 0)],
#  'DBCABGPA20182019': [('pumps', 1),
#   ('maintenance', 1),
#   ('bores', 1),
#   ('panel', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA10172019': [('unspsc', 1),
#   ('web', 1),
#   ('services', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCABGPA20152019': [('unspsc', 1),
#   ('upgrade', 1),
#   ('services', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCABGPA10162018': [('garden', 1),
#   ('conduct', 1),
#   ('botanic', 1),
#   ('kings', 1),
#   ('cinema', 1),
#   ('outdoor', 1),
#   ('park', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platform', 0)],
#  'DBCABGPA20162019': [('unspsc', 1),
#   ('realignment', 1),
#   ('path', 1),
#   ('zamia', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'BPB20230501': [('title', 1),
#   ('support', 1),
#   ('communications', 1),
#   ('strategy', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'BPB202201': [('burswood', 1),
#   ('free', 1),
#   ('supply', 1),
#   ('fittings', 1),
#   ('park', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('delivery', 1),
#   ('reticulation', 1),
#   ('fis', 1)],
#  'BPB12513': [('master', 1),
#   ('review', 1),
#   ('design', 1),
#   ('plan', 1),
#   ('park', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('rfq', 1),
#   ('platfrom', 0),
#   ('plasticware', 0)],
#  'RFQBPB202108': [('unspsc', 1),
#   ('sand', 1),
#   ('mulch', 1),
#   ('title', 1),
#   ('soil', 1),
#   ('provision', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'RFQBPB202104': [('burswood', 1),
#   ('security', 1),
#   ('park', 1),
#   ('services', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('player', 0),
#   ('platform', 0),
#   ('plastics', 0)],
#  'BPB201901': [('administration', 1),
#   ('provision', 1),
#   ('cleaning', 1),
#   ('burswood', 1),
#   ('toilets', 1),
#   ('office', 1),
#   ('services', 1),
#   ('public', 1),
#   ('unspsc', 1),
#   ('park', 1)],
#  'FINW0091123': [('burswood', 2),
#   ('park', 2),
#   ('unspsc', 1),
#   ('board', 1),
#   ('maintenance', 1),
#   ('title', 1),
#   ('modifications', 1),
#   ('shed', 1),
#   ('platforms', 0),
#   ('plasticware', 0)],
#  'FINW0079521': [('burswood', 1),
#   ('unspsc', 1),
#   ('path', 1),
#   ('board', 1),
#   ('park', 1),
#   ('title', 1),
#   ('high', 1),
#   ('quality', 1),
#   ('stage', 1),
#   ('shared', 1)],
#  'FINW0083822': [('development', 1),
#   ('unspsc', 1),
#   ('board', 1),
#   ('engineering', 1),
#   ('viewing', 1),
#   ('platform', 1),
#   ('title', 1),
#   ('park', 1),
#   ('specialists', 1),
#   ('panel', 1)],
#  'FINW0193521': [('construction', 1),
#   ('title', 1),
#   ('burswood', 1),
#   ('activities', 1),
#   ('unspsc', 1),
#   ('mattagarup', 1),
#   ('hydraulic', 1),
#   ('board', 1),
#   ('sewer', 1),
#   ('infrastructure', 1)],
#  'FINW0196721': [('park', 2),
#   ('burswood', 2),
#   ('board', 2),
#   ('artesian', 1),
#   ('bore', 1),
#   ('new', 1),
#   ('site', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('sinking', 1)],
#  'FINW0079521A': [('burswood', 2),
#   ('park', 1),
#   ('networks', 1),
#   ('board', 1),
#   ('building', 1),
#   ('stage', 1),
#   ('engineering', 1),
#   ('pathway', 1),
#   ('panel', 1),
#   ('unspsc', 1)],
#  'FINW0847220': [('specialists', 1),
#   ('title', 1),
#   ('park', 1),
#   ('matagarup', 1),
#   ('hydraulic', 1),
#   ('panel', 1),
#   ('building', 1),
#   ('board', 1),
#   ('unspsc', 1),
#   ('services', 1)],
#  'FIN0423419': [('burswood', 2),
#   ('park', 2),
#   ('unspsc', 1),
#   ('board', 1),
#   ('services', 1),
#   ('title', 1),
#   ('management', 1),
#   ('master', 1),
#   ('cost', 1),
#   ('plan', 1)],
#  'BMW0373219': [('park', 1),
#   ('burswood', 1),
#   ('bolton', 1),
#   ('landscape', 1),
#   ('embankment', 1),
#   ('avenue', 1),
#   ('unspsc', 1),
#   ('board', 1),
#   ('works', 1),
#   ('title', 1)],
#  'BMW0407219': [('park', 2),
#   ('burswood', 2),
#   ('drive', 1),
#   ('unspsc', 1),
#   ('board', 1),
#   ('mackay', 1),
#   ('roger', 1),
#   ('camfield', 1),
#   ('landscape', 1),
#   ('title', 1)],
#  'FIN0423319': [('burswood', 2),
#   ('park', 2),
#   ('title', 1),
#   ('architectural', 1),
#   ('plan', 1),
#   ('landscape', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('master', 1),
#   ('board', 1)],
#  'TWDT03532022': [('sector', 1),
#   ('program', 1),
#   ('training', 1),
#   ('title', 1),
#   ('assistance', 1),
#   ('department', 1),
#   ('employee', 1),
#   ('provision', 1),
#   ('tafe', 1),
#   ('workforce', 1)],
#  'CRTF230000626': [('whitelisting', 1),
#   ('digital', 1),
#   ('airlock', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('saas', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CRTF230000402': [('title', 1),
#   ('press', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('brake', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRT201904236A': [('services', 1),
#   ('masterclass', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('vessel', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CRTF230000263': [('unspsc', 1),
#   ('heavy', 1),
#   ('supply', 1),
#   ('machinery', 1),
#   ('title', 1),
#   ('plates', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF230000370': [('feature', 1),
#   ('water', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('maintenance', 1),
#   ('playgrounds', 0),
#   ('playing', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF220000634': [('unspsc', 1),
#   ('service', 1),
#   ('management', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'FINW0530022': [('title', 1),
#   ('unspsc', 1),
#   ('replacement', 1),
#   ('courtyard', 1),
#   ('regional', 1),
#   ('central', 1),
#   ('wall', 1),
#   ('tafe', 1),
#   ('block', 1),
#   ('platforms', 0)],
#  'CRTF220001044': [('heavy', 1),
#   ('truck', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('rigid', 1),
#   ('plate', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CRTF220000937': [('mount', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('suppression', 1),
#   ('dust', 1),
#   ('unit', 1),
#   ('skid', 1),
#   ('supply', 1),
#   ('plan', 0),
#   ('plasterboard', 0)],
#  'CRTF220000633': [('gardening', 1),
#   ('provision', 1),
#   ('central', 1),
#   ('regional', 1),
#   ('campus', 1),
#   ('services', 1),
#   ('northam', 1),
#   ('tafe', 1),
#   ('unspsc', 1),
#   ('title', 1)],
#  'CRTF220000857': [('unspsc', 1),
#   ('ip', 1),
#   ('telephony', 1),
#   ('services', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CRTF220000763': [('heavy', 1),
#   ('title', 1),
#   ('vehicle', 1),
#   ('supply', 1),
#   ('unspsc', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF220000786': [('licences', 1),
#   ('student', 1),
#   ('associated', 1),
#   ('simulation', 1),
#   ('training', 1),
#   ('title', 1),
#   ('patient', 1),
#   ('scenarios', 1),
#   ('software', 1),
#   ('supply', 1)],
#  'CRTF200001038': [('unspsc', 1),
#   ('training', 1),
#   ('services', 1),
#   ('specialised', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF210001002': [('red', 1),
#   ('training', 1),
#   ('holdings', 1),
#   ('dust', 1),
#   ('unspsc', 1),
#   ('assessment', 1),
#   ('worksites', 1),
#   ('pty', 1),
#   ('title', 1),
#   ('workplace', 1)],
#  'CRTF210000844': [('unspsc', 1),
#   ('campuses', 1),
#   ('services', 1),
#   ('security', 1),
#   ('provision', 1),
#   ('geraldton', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000431A': [('geraldton', 1),
#   ('campus', 1),
#   ('refresh', 1),
#   ('provision', 1),
#   ('tafe', 1),
#   ('title', 1),
#   ('food', 1),
#   ('unspsc', 1),
#   ('groceries', 1),
#   ('regional', 1)],
#  'CRTF210000966': [('unspsc', 1),
#   ('manikins', 1),
#   ('title', 1),
#   ('patient', 1),
#   ('simulation', 1),
#   ('software', 1),
#   ('associated', 1),
#   ('licences', 1),
#   ('playgrounds', 0),
#   ('platforms', 0)],
#  'CRTF210000763': [('kalgoorlie', 1),
#   ('title', 1),
#   ('campus', 1),
#   ('unspsc', 1),
#   ('plumbing', 1),
#   ('fitting', 1),
#   ('services', 1),
#   ('gas', 1),
#   ('planner', 0),
#   ('plasticware', 0)],
#  'CRTF210000713': [('unspsc', 1),
#   ('campus', 1),
#   ('northam', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CRTF210000718': [('auto', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('equipment', 1),
#   ('unspsc', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000622': [('auto', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('equipment', 1),
#   ('unspsc', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000431': [('food', 1),
#   ('title', 1),
#   ('campus', 1),
#   ('groceries', 1),
#   ('unspsc', 1),
#   ('provision', 1),
#   ('geraldton', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000432': [('disposal', 1),
#   ('title', 1),
#   ('waste', 1),
#   ('campuses', 1),
#   ('services', 1),
#   ('geraldton', 1),
#   ('unspsc', 1),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'TWDT0272020B': [('equipment', 1),
#   ('title', 1),
#   ('training', 1),
#   ('installation', 1),
#   ('provision', 1),
#   ('warranty', 1),
#   ('tafe', 1),
#   ('support', 1),
#   ('supply', 1),
#   ('various', 1)],
#  'CRTF210000419': [('electricity', 1),
#   ('campuses', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('northam', 1),
#   ('geraldton', 1),
#   ('kalgoorlie', 1),
#   ('player', 0),
#   ('platform', 0)],
#  'CRTF200000936': [('cleaning', 1),
#   ('central', 1),
#   ('regional', 1),
#   ('campus', 1),
#   ('northam', 1),
#   ('services', 1),
#   ('tafe', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0)],
#  'CRT01092020': [('network', 2),
#   ('title', 1),
#   ('order', 1),
#   ('form', 1),
#   ('site', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('connectivity', 1),
#   ('aasb', 0),
#   ('plastics', 0)],
#  'CRTF210000357': [('unspsc', 1),
#   ('campuses', 1),
#   ('services', 1),
#   ('refrigeration', 1),
#   ('title', 1),
#   ('geraldton', 1),
#   ('air', 1),
#   ('conditioning', 1),
#   ('mechanical', 1),
#   ('playgroup', 0)],
#  'DIOT201505637A': [('driving', 1),
#   ('training', 1),
#   ('services', 1),
#   ('panel', 1),
#   ('operations', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('specialised', 1),
#   ('plates', 0),
#   ('plastic', 0)],
#  'CRTF210000430': [('cloud', 1),
#   ('services', 1),
#   ('private', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF200000067': [('geraldton', 1),
#   ('title', 1),
#   ('campuses', 1),
#   ('cleaning', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CRTF200000946': [('training', 1),
#   ('services', 1),
#   ('assessment', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CRTF200001035': [('diesel', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('fuel', 1),
#   ('marine', 1),
#   ('wharf', 1),
#   ('unspsc', 1),
#   ('fishermans', 1),
#   ('geraldton', 1),
#   ('plastic', 0)],
#  'CRTF200000915': [('cleaning', 1),
#   ('campus', 1),
#   ('services', 1),
#   ('title', 1),
#   ('merredin', 1),
#   ('unspsc', 1),
#   ('tafe', 1),
#   ('regional', 1),
#   ('central', 1),
#   ('playgroup', 0)],
#  'CRTF210000503': [('unspsc', 1),
#   ('carnarvon', 1),
#   ('campus', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000504': [('unspsc', 1),
#   ('campus', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('geraldton', 1),
#   ('aasb', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CRTF210000506': [('unspsc', 1),
#   ('campus', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('geraldton', 1),
#   ('aasb', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CRTF200000914': [('moora', 1),
#   ('cleaning', 1),
#   ('regional', 1),
#   ('central', 1),
#   ('campus', 1),
#   ('services', 1),
#   ('tafe', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0)],
#  'CRTF200000923': [('aboriginal', 1),
#   ('branding', 1),
#   ('unspsc', 1),
#   ('project', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platforms', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF200000424': [('refrigeration', 1),
#   ('block', 1),
#   ('hvac', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('works', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CRTF210000507': [('kalgoorlie', 1),
#   ('campus', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CRTF210000505': [('merredin', 1),
#   ('moora', 1),
#   ('northam', 1),
#   ('campus', 1),
#   ('multifunctional', 1),
#   ('devices', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platinum', 0),
#   ('plate', 0)],
#  'CRTF200000704': [('unspsc', 1),
#   ('title', 1),
#   ('conversion', 1),
#   ('truck', 1),
#   ('playgrounds', 0),
#   ('plates', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('playing', 0)],
#  'CRTF200000505': [('disposal', 1),
#   ('campus', 1),
#   ('waste', 1),
#   ('title', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('kalgoorlie', 1),
#   ('pritish', 0),
#   ('plaques', 0),
#   ('plaster', 0)],
#  'CRTF200000107': [('unspsc', 1),
#   ('kalgoorlie', 1),
#   ('campus', 1),
#   ('training', 1),
#   ('services', 1),
#   ('specialised', 1),
#   ('title', 1),
#   ('plates', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CRT201904338B': [('park', 1),
#   ('technology', 1),
#   ('batavia', 1),
#   ('institute', 1),
#   ('coast', 1),
#   ('maritime', 1),
#   ('unspsc', 1),
#   ('geraldton', 1),
#   ('gardening', 1),
#   ('services', 1)],
#  'CRT201904236': [('services', 1),
#   ('masterclass', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('vessel', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'ETACRT201903227': [('kalgoorlie', 1),
#   ('central', 1),
#   ('services', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('lawn', 1),
#   ('tafe', 1),
#   ('unspsc', 1),
#   ('garden', 1),
#   ('care', 1)],
#  'CRTF190001225': [('title', 1),
#   ('electrical', 1),
#   ('campus', 1),
#   ('services', 1),
#   ('northam', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CRTF190001474': [('debit', 1),
#   ('direct', 1),
#   ('services', 1),
#   ('title', 1),
#   ('payment', 1),
#   ('fees', 1),
#   ('unspsc', 1),
#   ('student', 1),
#   ('playground', 0),
#   ('plastics', 0)],
#  'CRTF190001328': [('audit', 2),
#   ('training', 1),
#   ('unspsc', 1),
#   ('council', 1),
#   ('internal', 1),
#   ('services', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('academic', 1),
#   ('accreditation', 1)],
#  'CRTF190001251': [('motor', 1),
#   ('title', 1),
#   ('vehicle', 1),
#   ('campuses', 1),
#   ('servicing', 1),
#   ('geraldton', 1),
#   ('unspsc', 1),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'FINW0328323': [('campus', 1),
#   ('title', 1),
#   ('tafe', 1),
#   ('geraldton', 1),
#   ('block', 1),
#   ('unspsc', 1),
#   ('central', 1),
#   ('works', 1),
#   ('regional', 1),
#   ('toilet', 1)],
#  'FINW0690622': [('unspsc', 1),
#   ('central', 1),
#   ('internal', 1),
#   ('geraldton', 1),
#   ('tafe', 1),
#   ('title', 1),
#   ('campus', 1),
#   ('painting', 1),
#   ('regional', 1),
#   ('block', 1)],
#  'CC092023': [('unspsc', 1),
#   ('upgrade', 1),
#   ('lcms', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC062023': [('chromatography', 1),
#   ('unspsc', 1),
#   ('gas', 1),
#   ('delivery', 1),
#   ('spectrometer', 1),
#   ('supply', 1),
#   ('agilent', 1),
#   ('title', 1),
#   ('mass', 1),
#   ('installation', 1)],
#  'CC042023': [('gas', 1),
#   ('chromatography', 1),
#   ('purge', 1),
#   ('ptgcms', 1),
#   ('title', 1),
#   ('trap', 1),
#   ('mass', 1),
#   ('delivery', 1),
#   ('installation', 1),
#   ('spectrometer', 1)],
#  'CC052023': [('review', 1),
#   ('existing', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('laboratory', 1),
#   ('reconfigure', 1),
#   ('reports', 1),
#   ('playgrounds', 0),
#   ('platform', 0),
#   ('plasterglass', 0)],
#  'CC032023': [('infrastructure', 1),
#   ('network', 1),
#   ('ict', 1),
#   ('environment', 1),
#   ('security', 1),
#   ('services', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('aasb', 0)],
#  'CC112022': [('spectrometer', 1),
#   ('chromatography', 1),
#   ('liquid', 1),
#   ('title', 1),
#   ('mass', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('lcmsms', 1),
#   ('player', 0),
#   ('play', 0)],
#  'CC122022': [('flow', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('nutrient', 1),
#   ('analyser', 1),
#   ('title', 1),
#   ('continuous', 1),
#   ('player', 0),
#   ('plate', 0),
#   ('plasterglass', 0)],
#  'CC012023': [('coupled', 1),
#   ('liquid', 1),
#   ('detector', 1),
#   ('high', 1),
#   ('supply', 1),
#   ('array', 1),
#   ('chromatography', 1),
#   ('performance', 1),
#   ('unspsc', 1),
#   ('hplcdad', 1)],
#  'CC132022': [('supply', 1),
#   ('chromatographs', 1),
#   ('ic', 1),
#   ('ion', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CC102022': [('unspsc', 1),
#   ('inductively', 1),
#   ('plasma', 1),
#   ('title', 1),
#   ('emission', 1),
#   ('coupled', 1),
#   ('supply', 1),
#   ('spectrometer', 1),
#   ('optical', 1),
#   ('icpoes', 1)],
#  'CC012022': [('unspsc', 1),
#   ('financial', 1),
#   ('management', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('platform', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC132021': [('unspsc', 1),
#   ('software', 1),
#   ('technology', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('annual', 1),
#   ('support', 1),
#   ('licensed', 1),
#   ('platinum', 0),
#   ('plate', 0)],
#  'CC042022': [('spectrometer', 1),
#   ('triple', 1),
#   ('liquid', 1),
#   ('title', 1),
#   ('quadrupole', 1),
#   ('unspsc', 1),
#   ('chromatograph', 1),
#   ('mass', 1),
#   ('platinum', 0),
#   ('play', 0)],
#  'CC062022': [('delivery', 1),
#   ('spectroscopy', 1),
#   ('raman', 1),
#   ('portable', 1),
#   ('title', 1),
#   ('instrument', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('platinum', 0),
#   ('plate', 0)],
#  'CC072022': [('supply', 1),
#   ('title', 1),
#   ('fischer', 1),
#   ('karl', 1),
#   ('titrator', 1),
#   ('unspsc', 1),
#   ('instrument', 1),
#   ('plaster', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'CC052022': [('smiths', 1),
#   ('unspsc', 1),
#   ('elite', 1),
#   ('hazmatid', 1),
#   ('detection', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('player', 0),
#   ('play', 0)],
#  'CC082021': [('support', 1),
#   ('thermo', 1),
#   ('fisher', 1),
#   ('scientific', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CC082022': [('delivery', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('gcms', 1),
#   ('agilent', 1),
#   ('unspsc', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC022022': [('supply', 1),
#   ('analyser', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('carbon', 1),
#   ('delivery', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'CC032022': [('delivery', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('gcms', 1),
#   ('agilent', 1),
#   ('unspsc', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC032021': [('arrangement', 1),
#   ('supply', 1),
#   ('panel', 1),
#   ('reference', 1),
#   ('unspsc', 1),
#   ('materials', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CC162021': [('laboratory', 1),
#   ('support', 1),
#   ('information', 1),
#   ('forensic', 1),
#   ('unspsc', 1),
#   ('software', 1),
#   ('services', 1),
#   ('title', 1),
#   ('management', 1),
#   ('plate', 0)],
#  'CC152021': [('supply', 1),
#   ('forensic', 1),
#   ('title', 1),
#   ('immunoassay', 1),
#   ('delivery', 1),
#   ('unspsc', 1),
#   ('kits', 1),
#   ('racing', 1),
#   ('platinum', 0),
#   ('platfrom', 0)],
#  'CC062021': [('provision', 1),
#   ('unspsc', 1),
#   ('pv', 1),
#   ('technologies', 1),
#   ('craic', 1),
#   ('title', 1),
#   ('microspectrophotometer', 1),
#   ('uvvisiblenir', 1),
#   ('player', 0),
#   ('plates', 0)],
#  'CC112021': [('delivery', 1),
#   ('needles', 1),
#   ('supply', 1),
#   ('tubes', 1),
#   ('title', 1),
#   ('heparin', 1),
#   ('unspsc', 1),
#   ('lithium', 1),
#   ('platform', 0),
#   ('plasterglass', 0)],
#  'CC072021': [('cabinets', 2),
#   ('biological', 1),
#   ('delivery', 1),
#   ('disposal', 1),
#   ('supply', 1),
#   ('safety', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CC042021': [('resolution', 1),
#   ('spectrometer', 1),
#   ('lcms', 1),
#   ('liquid', 1),
#   ('chromatographhigh', 1),
#   ('unspsc', 1),
#   ('mass', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('platform', 0)],
#  'CC052021': [('ultimate', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('rsl', 1),
#   ('title', 1),
#   ('cnano', 1),
#   ('unspsc', 1),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'CC012021': [('precision', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('diluter', 1),
#   ('static', 1),
#   ('playground', 0),
#   ('plasterboard', 0),
#   ('playgrounds', 0)],
#  'CC022021': [('supply', 1),
#   ('xrf', 1),
#   ('bruker', 1),
#   ('tracer', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('play', 0),
#   ('player', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'CC122020': [('supply', 1),
#   ('title', 1),
#   ('gas', 1),
#   ('spectrometry', 1),
#   ('chromatography', 1),
#   ('quadrupole', 1),
#   ('mass', 1),
#   ('unspsc', 1),
#   ('triple', 1),
#   ('delivery', 1)],
#  'CC102020': [('maintenance', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('equipment', 1),
#   ('agilent', 1),
#   ('title', 1),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0),
#   ('platform', 0)],
#  'CC112020': [('laboratory', 1),
#   ('information', 1),
#   ('unspsc', 1),
#   ('modernisation', 1),
#   ('title', 1),
#   ('management', 1),
#   ('aasb', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CC092020': [('plasma', 1),
#   ('mass', 1),
#   ('delivery', 1),
#   ('couple', 1),
#   ('supply', 1),
#   ('inductively', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('spectrometer', 1),
#   ('icpms', 1)],
#  'CC082020': [('accessories', 1),
#   ('title', 1),
#   ('supply', 1),
#   ('filmarray', 1),
#   ('instrument', 1),
#   ('unspsc', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC062020': [('resolution', 1),
#   ('chromatographhigh', 1),
#   ('liquid', 1),
#   ('title', 1),
#   ('mass', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('spectrometer', 1),
#   ('lcms', 1),
#   ('play', 0)],
#  'CC052020': [('onelims', 1),
#   ('business', 1),
#   ('technical', 1),
#   ('analyst', 1),
#   ('services', 1),
#   ('project', 1),
#   ('unspsc', 1),
#   ('support', 1),
#   ('title', 1),
#   ('platform', 0)],
#  'CC072020': [('storage', 2),
#   ('title', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('poweredge', 1),
#   ('array', 1),
#   ('server', 1),
#   ('expansion', 1),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC012020': [('supply', 1),
#   ('analyser', 1),
#   ('mercury', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('delivery', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'CC042020': [('delivery', 1),
#   ('unspsc', 1),
#   ('hclass', 1),
#   ('plus', 1),
#   ('waters', 1),
#   ('title', 1),
#   ('uplc', 1),
#   ('supply', 1),
#   ('acquity', 1),
#   ('platinum', 0)],
#  'CC032020': [('auto', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('titration', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('play', 0),
#   ('platinum', 0),
#   ('plasterboard', 0),
#   ('playgroup', 0)],
#  'CC092019': [('edx', 1),
#   ('microscope', 1),
#   ('gunshot', 1),
#   ('sem', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('fe', 1),
#   ('microanalysis', 1),
#   ('xray', 1),
#   ('energy', 1)],
#  'CC112019': [('supply', 1),
#   ('analyser', 1),
#   ('nitrogen', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('carbon', 1),
#   ('delivery', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CC022020': [('domestic', 1),
#   ('service', 1),
#   ('title', 1),
#   ('medical', 1),
#   ('container', 1),
#   ('industrial', 1),
#   ('speciality', 1),
#   ('unspsc', 1),
#   ('gases', 1),
#   ('supply', 1)],
#  'CC082019': [('support', 1),
#   ('thermo', 1),
#   ('fisher', 1),
#   ('scientific', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'CC082019A': [('unspsc', 1),
#   ('title', 1),
#   ('onelims', 1),
#   ('project', 1),
#   ('phase', 1),
#   ('foundation', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'CC102019': [('unit', 1),
#   ('title', 1),
#   ('condensing', 1),
#   ('remote', 1),
#   ('unspsc', 1),
#   ('custom', 1),
#   ('freezer', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'FINW0066022': [('level', 2),
#   ('street', 1),
# ...
#  'DBCA422WQ602021': [('ningaloo', 1),
#   ('reserve', 1),
#   ('unspsc', 1),
#   ('project', 1),
#   ('coastal', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('track', 1),
#   ('plain', 0),
#   ('plasterglass', 0)],
#  'DBCA376012020': [('supply', 1),
#   ('title', 1),
#   ('operation', 1),
#   ('oxygen', 1),
#   ('equipment', 1),
#   ('oxygenation', 1),
#   ('liquid', 1),
#   ('unspsc', 1),
#   ('maintenance', 1),
#   ('plastics', 0)],
#  'DBCA404WM902021': [('vehicle', 1),
#   ('modify', 1),
#   ('title', 1),
#   ('heavy', 1),
#   ('relocate', 1),
#   ('unspsc', 1),
#   ('design', 1),
#   ('centre', 1),
#   ('shed', 1),
#   ('work', 1)],
#  'DBCA243SQ742021': [('government', 1),
#   ('building', 1),
#   ('capacity', 1),
#   ('title', 1),
#   ('bodies', 1),
#   ('unspsc', 1),
#   ('management', 1),
#   ('training', 1),
#   ('joint', 1),
#   ('play', 0)],
#  'DBCA427GQ722021': [('delivery', 1),
#   ('mixer', 1),
#   ('mincer', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('playground', 0),
#   ('player', 0),
#   ('plastic', 0),
#   ('playspace', 0)],
#  'DBCA428WQ802021': [('construction', 1),
#   ('jetty', 1),
#   ('bassendean', 1),
#   ('beach', 1),
#   ('reserve', 1),
#   ('unspsc', 1),
#   ('sandy', 1),
#   ('title', 1),
#   ('replacement', 1),
#   ('plastics', 0)],
#  'DBCA243WQ942021': [('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCA759SQ842021': [('dbcas', 1),
#   ('network', 1),
#   ('title', 1),
#   ('services', 1),
#   ('country', 1),
#   ('unspsc', 1),
#   ('satellite', 1),
#   ('state', 1),
#   ('playground', 0),
#   ('playing', 0)],
#  'DBCA421WM832021': [('point', 1),
#   ('title', 1),
#   ('station', 1),
#   ('steep', 1),
#   ('shed', 1),
#   ('ranger', 1),
#   ('unspsc', 1),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'dbca243SQ692021': [('region', 1),
#   ('assessment', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('classification', 1),
#   ('coast', 1),
#   ('road', 1),
#   ('south', 1),
#   ('playgrounds', 0),
#   ('plastic', 0)],
#  'DBCA411WQ632021': [('brook', 1),
#   ('unspsc', 1),
#   ('donnelly', 1),
#   ('big', 1),
#   ('title', 1),
#   ('resealing', 1),
#   ('burma', 1),
#   ('district', 1),
#   ('dam', 1),
#   ('roads', 1)],
#  'DBCA411WQ732021': [('carpark', 1),
#   ('asphalting', 1),
#   ('falls', 1),
#   ('unspsc', 1),
#   ('beedelup', 1),
#   ('title', 1),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA404WM792021': [('construction', 1),
#   ('stage', 1),
#   ('bilya', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('wiilman', 1),
#   ('trails', 1),
#   ('walk', 1),
#   ('playground', 0),
#   ('plastic', 0)],
#  'DBCA408WT592021': [('replacement', 1),
#   ('unspsc', 1),
#   ('geogrup', 1),
#   ('title', 1),
#   ('boardwalk', 1),
#   ('lake', 1),
#   ('playground', 0),
#   ('playgroup', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'DBCA421WM812021': [('title', 1),
#   ('hybrid', 1),
#   ('station', 1),
#   ('steep', 1),
#   ('ranger', 1),
#   ('unspsc', 1),
#   ('point', 1),
#   ('solar', 1),
#   ('aasb', 0),
#   ('plasterboard', 0)],
#  'DBCA243WT682021': [('unspsc', 1),
#   ('mountain', 1),
#   ('redevelopment', 1),
#   ('park', 1),
#   ('goat', 1),
#   ('phase', 1),
#   ('title', 1),
#   ('bike', 1),
#   ('farm', 1),
#   ('design', 1)],
#  'DBCA430WQ702021': [('dual', 1),
#   ('resurfacing', 1),
#   ('use', 1),
#   ('path', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('graham', 1),
#   ('reserve', 1),
#   ('john', 1),
#   ('plates', 0)],
#  'DBCA423WQ502021': [('construction', 1),
#   ('karijini', 1),
#   ('park', 1),
#   ('title', 1),
#   ('national', 1),
#   ('unspsc', 1),
#   ('visitor', 1),
#   ('falls', 1),
#   ('fortescue', 1),
#   ('path', 1)],
#  'DBCA422WM652021': [('construction', 1),
#   ('park', 1),
#   ('stacks', 1),
#   ('block', 1),
#   ('range', 1),
#   ('oyster', 1),
#   ('toilet', 1),
#   ('unspsc', 1),
#   ('national', 1),
#   ('cape', 1)],
#  'DBCA429WQ622021': [('upgrades', 1),
#   ('jane', 1),
#   ('john', 1),
#   ('unspsc', 1),
#   ('national', 1),
#   ('forrest', 1),
#   ('path', 1),
#   ('park', 1),
#   ('title', 1),
#   ('promenade', 1)],
#  'DBCA404WT222021': [('road', 1),
#   ('title', 1),
#   ('precinct', 1),
#   ('wellington', 1),
#   ('unspsc', 1),
#   ('dam', 1),
#   ('carpark', 1),
#   ('upgrades', 1),
#   ('planned', 0),
#   ('places', 0)],
#  'DBCA411WQ302021': [('design', 1),
#   ('construct', 1),
#   ('new', 1),
#   ('pontoon', 1),
#   ('unspsc', 1),
#   ('donnelly', 1),
#   ('title', 1),
#   ('landing', 1),
#   ('boat', 1),
#   ('jetty', 1)],
#  'DBCA440012019A': [('title', 1),
#   ('rotary', 1),
#   ('aerial', 1),
#   ('wing', 1),
#   ('activities', 1),
#   ('ignition', 1),
#   ('associated', 1),
#   ('unspsc', 1),
#   ('aircraft', 1),
#   ('suppression', 1)],
#  'DBCA413WM612021': [('unspsc', 1),
#   ('avenue', 1),
#   ('frankland', 1),
#   ('park', 1),
#   ('walpole', 1),
#   ('ablutions', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA411WQ252021': [('rd', 2),
#   ('title', 1),
#   ('dentrecasteaux', 1),
#   ('beach', 1),
#   ('unspsc', 1),
#   ('falls', 1),
#   ('beedelup', 1),
#   ('dr', 1),
#   ('reseal', 1),
#   ('salmon', 1)],
#  'DBCA414WM272021B': [('assembly', 2),
#   ('toilet', 2),
#   ('unspsc', 1),
#   ('title', 1),
#   ('cave', 1),
#   ('burra', 1),
#   ('rock', 1),
#   ('hill', 1),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCA409SQ442021': [('purnululu', 1),
#   ('national', 1),
#   ('architectural', 1),
#   ('visitors', 1),
#   ('centre', 1),
#   ('services', 1),
#   ('new', 1),
#   ('park', 1),
#   ('unspsc', 1),
#   ('title', 1)],
#  'DBCA408WT422021': [('title', 1),
#   ('construction', 1),
#   ('block', 1),
#   ('toilet', 1),
#   ('island', 1),
#   ('unspsc', 1),
#   ('penguin', 1),
#   ('aasb', 0),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCA413WQ242021': [('road', 1),
#   ('valley', 1),
#   ('title', 1),
#   ('reseal', 1),
#   ('unspsc', 1),
#   ('giants', 1),
#   ('playgrounds', 0),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA423WQ392021': [('woodland', 1),
#   ('demolition', 1),
#   ('karratha', 1),
#   ('cleanup', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('rd', 1),
#   ('lot', 1),
#   ('aasb', 0),
#   ('platforms', 0)],
#  'DBCA427012020': [('title', 1),
#   ('kalgulup', 1),
#   ('unspsc', 1),
#   ('regional', 1),
#   ('weed', 1),
#   ('control', 1),
#   ('provision', 1),
#   ('mapping', 1),
#   ('services', 1),
#   ('park', 1)],
#  'DBCA420WQ452021': [('lake', 1),
#   ('park', 1),
#   ('seal', 1),
#   ('asphalt', 1),
#   ('thetis', 1),
#   ('car', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platforms', 0)],
#  'DBCA413WT232021': [('coalmine', 1),
#   ('unspsc', 1),
#   ('road', 1),
#   ('beach', 1),
#   ('reseal', 1),
#   ('title', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA430WT172021': [('boardwalk', 1),
#   ('olive', 1),
#   ('lake', 1),
#   ('seymour', 1),
#   ('herdsman', 1),
#   ('unspsc', 1),
#   ('redevelopment', 1),
#   ('title', 1),
#   ('plasticware', 0),
#   ('plaster', 0)],
#  'DBCA404WM582021': [('lake', 1),
#   ('installation', 1),
#   ('humps', 1),
#   ('unspsc', 1),
#   ('speed', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('kepwari', 1),
#   ('aasb', 0),
#   ('plate', 0)],
#  'DBCA760022019': [('title', 1),
#   ('unspsc', 1),
#   ('services', 1),
#   ('assistance', 1),
#   ('provision', 1),
#   ('employee', 1),
#   ('program', 1),
#   ('playground', 0),
#   ('playgroup', 0),
#   ('plastic', 0)],
#  'DBCA404WM562021': [('flora', 1),
#   ('site', 1),
#   ('title', 1),
#   ('works', 1),
#   ('unspsc', 1),
#   ('lookout', 1),
#   ('road', 1),
#   ('playgrounds', 0),
#   ('playground', 0),
#   ('plasterglass', 0)],
#  'DBCA421GQ542021': [('upgrade', 1),
#   ('timber', 1),
#   ('landscape', 1),
#   ('mia', 1),
#   ('accoya', 1),
#   ('unspsc', 1),
#   ('project', 1),
#   ('supply', 1),
#   ('monkey', 1),
#   ('title', 1)],
#  'DBCA404WM482021': [('road', 1),
#   ('reseal', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('flora', 1),
#   ('plagiarism', 0),
#   ('platfrom', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA414WM122021C': [('replacement', 1),
#   ('roof', 1),
#   ('lake', 1),
#   ('station', 1),
#   ('mason', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('platform', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA408WM462021': [('yanchep', 1),
#   ('road', 1),
#   ('np', 1),
#   ('stabilisation', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('platform', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA404WT042021': [('collie', 2),
#   ('suspension', 1),
#   ('bridge', 1),
#   ('trails', 1),
#   ('river', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('adventure', 1),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA408WQ262021': [('old', 1),
#   ('resurfacing', 1),
#   ('title', 1),
#   ('yanchep', 1),
#   ('unspsc', 1),
#   ('road', 1),
#   ('playgrounds', 0),
#   ('playground', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA538SQ282021': [('title', 1),
#   ('unspsc', 1),
#   ('canning', 1),
#   ('phytoplankton', 1),
#   ('analyses', 1),
#   ('swan', 1),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCA401WT662020': [('canal', 1),
#   ('jetty', 1),
#   ('unspsc', 1),
#   ('ramp', 1),
#   ('boat', 1),
#   ('title', 1),
#   ('rocks', 1),
#   ('plain', 0),
#   ('placemaking', 0),
#   ('plasterglass', 0)],
#  'DBCA404WQ352021': [('car', 1),
#   ('unspsc', 1),
#   ('bays', 1),
#   ('parking', 1),
#   ('title', 1),
#   ('gathering', 1),
#   ('trails', 1),
#   ('areas', 1),
#   ('walk', 1),
#   ('construct', 1)],
#  'DBCA417012020': [('esperance', 1),
#   ('plant', 1),
#   ('maintain', 1),
#   ('operators', 1),
#   ('title', 1),
#   ('district', 1),
#   ('unspsc', 1),
#   ('parks', 1),
#   ('roads', 1),
#   ('firebreaks', 1)],
#  'DBCA429WQ162021': [('national', 1),
#   ('title', 1),
#   ('installation', 1),
#   ('park', 1),
#   ('toilet', 1),
#   ('serpentine', 1),
#   ('prefabrication', 1),
#   ('unspsc', 1),
#   ('plastic', 0),
#   ('plastics', 0)],
#  'DBCA419WQ322021': [('title', 1),
#   ('wallabi', 1),
#   ('parking', 1),
#   ('airstrip', 1),
#   ('island', 1),
#   ('area', 1),
#   ('unspsc', 1),
#   ('east', 1),
#   ('expansion', 1),
#   ('aasb', 0)],
#  'DBCA419WT012021': [('islands', 2),
#   ('title', 1),
#   ('wallabi', 1),
#   ('houtman', 1),
#   ('beacon', 1),
#   ('abrolhos', 1),
#   ('national', 1),
#   ('unspsc', 1),
#   ('park', 1),
#   ('jetties', 1)],
#  'DBCA416GQ37021': [('national', 1),
#   ('message', 1),
#   ('park', 1),
#   ('river', 1),
#   ('title', 1),
#   ('fitzgerald', 1),
#   ('unspsc', 1),
#   ('variable', 1),
#   ('signs', 1),
#   ('player', 0)],
#  'DBCA429WQ132021': [('construction', 1),
#   ('unspsc', 1),
#   ('phase', 1),
#   ('title', 1),
#   ('redevelopment', 1),
#   ('trail', 1),
#   ('goat', 1),
#   ('mountain', 1),
#   ('farm', 1),
#   ('bike', 1)],
#  'DBCA754062020': [('oracle', 2),
#   ('financials', 1),
#   ('hosting', 1),
#   ('application', 1),
#   ('unspsc', 1),
#   ('databases', 1),
#   ('prod', 1),
#   ('title', 1),
#   ('upgrade', 1),
#   ('dbca', 1)],
#  'DBCA423WT092021': [('title', 1),
#   ('construction', 1),
#   ('dales', 1),
#   ('toilet', 1),
#   ('national', 1),
#   ('unspsc', 1),
#   ('karijini', 1),
#   ('campground', 1),
#   ('park', 1),
#   ('aasb', 0)],
#  'DBCA758032020': [('research', 1),
#   ('unspsc', 1),
#   ('advisory', 1),
#   ('services', 1),
#   ('title', 1),
#   ('provision', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA401WT052021': [('construction', 1),
#   ('title', 1),
#   ('network', 1),
#   ('trail', 1),
#   ('pines', 1),
#   ('unspsc', 1),
#   ('bike', 1),
#   ('design', 1),
#   ('mountain', 1),
#   ('planner', 0)],
#  'DBCA404WT022020': [('mountain', 1),
#   ('bike', 1),
#   ('park', 1),
#   ('title', 1),
#   ('national', 1),
#   ('network', 1),
#   ('unspsc', 1),
#   ('design', 1),
#   ('trail', 1),
#   ('wellington', 1)],
#  'DBCA420WQ642020': [('shack', 2),
#   ('title', 1),
#   ('removal', 1),
#   ('settlements', 1),
#   ('grey', 1),
#   ('unspsc', 1),
#   ('wedge', 1),
#   ('aasb', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0)],
#  'DBCA539S012021': [('initiation', 1),
#   ('office', 1),
#   ('biodiversity', 1),
#   ('repository', 1),
#   ('information', 1),
#   ('unspsc', 1),
#   ('data', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('platforms', 0)],
#  'DBCA423WQ142021': [('dbca', 1),
#   ('title', 1),
#   ('new', 1),
#   ('shed', 1),
#   ('unspsc', 1),
#   ('depot', 1),
#   ('coral', 1),
#   ('marine', 1),
#   ('bay', 1),
#   ('plant', 0)],
#  'DBCA752GQ012021': [('delivery', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('tipping', 1),
#   ('title', 1),
#   ('bodies', 1),
#   ('plaster', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA752052020': [('supply', 1),
#   ('loader', 1),
#   ('title', 1),
#   ('deck', 1),
#   ('spread', 1),
#   ('unspsc', 1),
#   ('low', 1),
#   ('playground', 0),
#   ('platform', 0),
#   ('plastic', 0)],
#  'DBCA404WQ112021': [('flora', 1),
#   ('road', 1),
#   ('upgrade', 1),
#   ('stage', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('platform', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA404WV122020': [('frames', 1),
#   ('supply', 1),
#   ('installing', 1),
#   ('hdg', 1),
#   ('toilet', 1),
#   ('unspsc', 1),
#   ('assist', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plate', 0)],
#  'DBCA404WM202020': [('lake', 1),
#   ('unspsc', 1),
#   ('repairs', 1),
#   ('title', 1),
#   ('kepwari', 1),
#   ('corner', 1),
#   ('widening', 1),
#   ('resealing', 1),
#   ('entry', 1),
#   ('potholecrack', 1)],
#  'DBCA752GQ022021': [('unspsc', 1),
#   ('tractor', 1),
#   ('supply', 1),
#   ('slasher', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA371012020': [('support', 1),
#   ('software', 1),
#   ('unspsc', 1),
#   ('provision', 1),
#   ('title', 1),
#   ('maintenance', 1),
#   ('remsoft', 1),
#   ('plan', 0),
#   ('plasterglass', 0),
#   ('plastics', 0)],
#  'DBCA770WM212021': [('title', 1),
#   ('suite', 1),
#   ('block', 1),
#   ('edit', 1),
#   ('control', 1),
#   ('unspsc', 1),
#   ('aasb', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0)],
#  'DBCA754032020': [('cleaning', 1),
#   ('kensington', 1),
#   ('provision', 1),
#   ('operations', 1),
#   ('head', 1),
#   ('title', 1),
#   ('complex', 1),
#   ('unspsc', 1),
#   ('quarters', 1),
#   ('state', 1)],
#  'DBCA758012020': [('managed', 1),
#   ('services', 1),
#   ('data', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('aasb', 0),
#   ('plasterglass', 0),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA424WQ572020': [('amenities', 1),
#   ('title', 1),
#   ('construction', 1),
#   ('convenience', 1),
#   ('site', 1),
#   ('gurlbinwila', 1),
#   ('recreation', 1),
#   ('unspsc', 1),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA429012019': [('unspsc', 1),
#   ('supply', 1),
#   ('concrete', 1),
#   ('title', 1),
#   ('delivery', 1),
#   ('platforms', 0),
#   ('plastics', 0),
#   ('plasticware', 0),
#   ('plate', 0),
#   ('plates', 0)],
#  'DBCA404WM072021': [('vehicle', 1),
#   ('harvey', 1),
#   ('centre', 1),
#   ('shed', 1),
#   ('unspsc', 1),
#   ('heavy', 1),
#   ('work', 1),
#   ('title', 1),
#   ('design', 1),
#   ('construct', 1)],
#  'DBCA424012020': [('rowley', 1),
#   ('unspsc', 1),
#   ('marine', 1),
#   ('park', 1),
#   ('maintenance', 1),
#   ('title', 1),
#   ('inspection', 1),
#   ('moorings', 1),
#   ('shoals', 1),
#   ('platinum', 0)],
#  'DBCA752012020': [('type', 1),
#   ('unspsc', 1),
#   ('track', 1),
#   ('title', 1),
#   ('diesel', 1),
#   ('powered', 1),
#   ('delivery', 1),
#   ('supply', 1),
#   ('bulldozers', 1),
#   ('playgrounds', 0)],
#  'DBCA752042019B': [('delivery', 1),
#   ('bonnetd', 1),
#   ('prime', 1),
#   ('supply', 1),
#   ('movers', 1),
#   ('unspsc', 1),
#   ('title', 1),
#   ('plastic', 0),
#   ('plastics', 0),
#   ('plasticware', 0)],
#  'DBCA420WQ462020B': [('title', 1),
#   ('desert', 1),
#   ('waste', 1),
#   ('pinnacles', 1),
#   ('installation', 1),
#   ('discovery', 1),
#   ('unspsc', 1),
#   ('water', 1),
#   ('supply', 1),
#   ('secondary', 1)],
#  'DBCA417WM082021': [('le', 1),
#   ('kitchen', 1),
#   ('camp', 1),
#   ('grand', 1),
#   ('title', 1),
#   ('ii', 1),
#   ('block', 1),
#   ('cape', 1),
#   ('stage', 1),
#   ('works', 1)],
#  'DBCA754042020': [('title', 1),
#   ('unspsc', 1),
#   ('supply', 1),
#   ('reticulated', 1),
#   ('gas', 1),
#   ('playground', 0),
#   ('player', 0),
#   ('plasterboard', 0),
#   ('plasterglass', 0),
#   ('plastic', 0)],
#  'DBCA754052020': [('electricity', 2),
#   ('kensington', 1),
#   ('supply', 1),
#   ('title', 1),
#   ('unspsc', 1),
#   ('player', 0),
#   ('plates', 0),
#   ('plasterglass', 0),
#   ('playgroup', 0),
#   ('plastic', 0)],
#  'DBCA419WT552020': [('houtman', 1),
#   ('title', 1),
#   ('abrolhos', 1),
#   ('airstrip', 1),
#   ('national', 1),
#   ('park', 1),
#   ('unspsc', 1),
#   ('islands', 1),
#   ('maintenance', 1),
#   ('plastic', 0)],
#  ...}
