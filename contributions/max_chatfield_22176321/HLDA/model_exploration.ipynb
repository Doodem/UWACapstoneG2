# %%
import tomotopy as tp
hlda = tp.HLDAModel.load("struc_tender.hlda.tmm")

# %%
hpa = tp.HPAModel.load("struc_tender.hpa.tmm")

# %%
hpa.summary()
# Out:
# <Basic Info>
# | HPAModel (current version: 0.12.5)
# | 20625 docs, 614519 words
# | Total Vocabs: 24872, Used Vocabs: 24872
# | Entropy of words: 7.70177
# | Entropy of term-weighted words: 7.70177
# | Removed Vocabs: <NA>
# |
# <Training Info>
# | Iterations: 300, Burn-in steps: 0
# | Optimization Interval: 1
# | Log-likelihood per word: -9.68023
# |
# <Initial Parameters>
# | tw: TermWeight.ONE
# | min_cf: 0 (minimum collection frequency of words)
# | min_df: 0 (minimum document frequency of words)
# | rm_top: 0 (the number of top words to be removed)
# | k1: 10 (the number of super topics between 1 ~ 32767)
# | k2: 100 (the number of sub topics between 1 ~ 32767)
# | alpha: [0.1] (initial hyperparameter of Dirichlet distribution for document-topic, given as a single `float` in case of symmetric prior and as a list with length `k1 + 1` of `float` in case of asymmetric prior.)
# ...

# %%
print(hpa.docs[1])
hpa.docs[1].topics
# Out:
# <tomotopy.Document with words="bar consultancy staffing agwa rooftop bar agwa café bar art gallery western australia agwa requires services consultant assist day day running agwa rooftop bar agwa café bar rooftop bar opens three nights per week friday sunday general public well special hired events bar offers best west australian inspired food beverage 3pm evenings since opening november 2021 agwa rooftop bar welcomed 000 people premises recently opened agwa café bar april 2022 operates seven days week 5pm offering coffee lunch snacks well running bar afternoon café bar serves food beverage local producers endeavours serve best coffee food perth successful consultant responsible daily operation bar café including provision venue manager logistical staff bar cafe staff agwa rooftop bar agwa café bar new operations agwa looking someone experience share expertise knowledge grow business offer advice improve customer experience note liquor license held art gallery western australia opera
# ...
